# %%
# 必要なライブラリのインクルード
import os
from math import *
import re
import cv2
from PIL import Image as pilim
from PIL import ImageFilter
import matplotlib.pyplot as plt
import numpy as np
# opencv画像入力用
from IPython.display import display, Image

# %matplotlib inline
def display_cv_image(image, format='.JPG'):
    decoded_bytes = cv2.imencode(format, image)[1].tobytes()
    display(Image(data=decoded_bytes))
    
def resizeAndShow(img,num):
    size = (4*num,4*num)
    show_img = cv2.resize(img, size)
    display_cv_image(show_img)

# %%
import skimage.transform  
# from PIL import Image  
import numpy as np  

def distort(file_path, roi_points, from_points, to_points):  
    im = pilim.open(file_path).convert('RGBA')  
    from_points = np.concatenate((roi_points, from_points))  
    to_points = np.concatenate((roi_points, to_points))  
    affin = skimage.transform.PiecewiseAffineTransform()  
    affin.estimate(to_points, from_points)  
    im_array = skimage.transform.warp(im, affin)  
    im_array = np.array(im_array * 255., dtype=np.uint8)  
    if im_array.shape[2] == 1:  
        im_array = im_array.reshape((im_array.shape[0],im_array.shape[1]))  
    warped_im = pilim.fromarray(im_array, 'RGBA')  
    im.paste(warped_im, (0, 0), warped_im)  
    return im  

file_path = './img/test.jpg'  
roi_points = [(100,100),(200,100),(200,200),(100,200)]  
from_points = [(100,100),(200,100),(200,200),(100,200)]  
to_points = [(120,120),(180,120),(180,180),(120,180)]  
im = distort(file_path, roi_points, from_points, to_points)


#RGB変換
im = im.convert("RGB")
im.save('./img/output.jpg') #変形後の写真

# %%
original_img = cv2.imread("./img/test.jpg")
img = cv2.imread("./img/output.jpg")
check_img = original_img
check_vec_img = original_img

#ベクトルだけの表示
cv2.rectangle(check_vec_img, roi_points[0], roi_points[2], (0, 0, 255), 1)
for i in range(0,len(from_points)):
    cv2.line(check_vec_img, from_points[i], to_points[i], (255, 255, 255), 3)
    cv2.line(check_vec_img, to_points[i], to_points[i], (255, 0, 0), 5)


original_img = cv2.imread("./img/test.jpg")
print("原画")
display_cv_image(original_img)
print("ベクトル場")
display_cv_image(check_vec_img)
print("結果")
display_cv_image(img)
# Out:
# 原画
# ベクトル場
# 結果

# %%
face_cascade = cv2.CascadeClassifier('/usr/local/Cellar/opencv/3.3.0_3/share/OpenCV/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('/usr/local/Cellar/opencv/3.3.0_3/share/OpenCV/haarcascades/haarcascade_eye.xml')



# イメージファイルの読み込み
mouse_img = cv2.imread('./img/before.jpg')

# 顔を検知
# def extractEye(img):
#     eye_rect = [(0,0),(0,0)]
#     eye_size = [(0,0),(0,0)]
#     faces = face_cascade.detectMultiScale(img)
#     counter = 0
# #     face_counter = 0
#     for (x,y,w,h) in faces:
#         print("face!")
# #         face_counter += 1
#         # 検知した顔を矩形で囲む
# #         cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)

#         # 顔画像（グレースケール）
#         roi_gray = img[y:y+h, x:x+w]
#         # 顔画像（カラースケール）
#         roi_color = img[y:y+h, x:x+w]
#         # 顔の中から目を検知
#         eyes = eye_cascade.detectMultiScale(roi_gray)
#         for (ex,ey,ew,eh) in eyes:
#             # 検知した目を矩形で囲む
#             if(counter>=2):
#                 break
# #             cv2.rectangle(roi_color,(ex,ey+int(eh/4)),(ex+ew,ey+int(eh*3/4)),(0,255,0),2)
#             eye_rect[counter] = (ex+x,ey+y)
#             eye_size[counter] = (ew,eh)
#             counter +=1
    
#     if(counter != 2):
#         print("目が正確に検出できませんでした。",counter)

    
# #     print("顔の個数:",face_counter)
#     if (eye_rect[0][0]<eye_rect[1][0]):
#         return eye_rect,eye_size
#     else:
# #         print("左右変更")
#         tmp_rect = eye_rect[1]
#         tmp_size = eye_size[1]
#         eye_rect[1] = eye_rect[0]
#         eye_rect[0] = tmp_rect
#         eye_size[1] = eye_size[0]
#         eye_size[0] = tmp_size
#         return eye_rect,eye_size


all_roi_points = []
roi_points = []  
from_points = []  
to_points = [] 


# グレースケール変換
gray = cv2.cvtColor(mouse_img, cv2.COLOR_BGR2GRAY)

eye_count = 0
# 顔を検知
faces = face_cascade.detectMultiScale(gray)
for (x,y,w,h) in faces:
    # 検知した顔を矩形で囲む
    cv2.rectangle(mouse_img,(x,y),(x+w,y+h),(255,0,0),2)
    # 顔画像（グレースケール）
    roi_gray = gray[y:y+h, x:x+w]
    # 顔ｇ増（カラースケール）
    roi_color = mouse_img[y:y+h, x:x+w]
    # 顔の中から目を検知
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        if (eye_count >=1):#一旦片目で
            break
        # 検知した目を矩形で囲む
        if (ey <= h/3): #目の位置は顔の四角よりも1/3より上にあるはずなので
            #cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
            #変形させる四角形の定義
            all_roi_points.append((ex+x+int(ew/10),ey+y+int(eh/4)))
            all_roi_points.append((ex+x+ew-int(ew/10),ey+y+int(eh/4)))
            all_roi_points.append((ex+x+ew-int(ew/10),ey+y+eh-int(eh/4)))
            all_roi_points.append((ex+x+int(ew/10),ey+y+eh-int(eh/4)))
            
            eye_count += 1

# 画像表示

display_cv_image(mouse_img)

move_x = 4

roi_points.append(all_roi_points[0])
roi_points.append(all_roi_points[1])
roi_points.append(all_roi_points[2])
roi_points.append(all_roi_points[3])

from_points.append(roi_points[0])
from_points.append(roi_points[1])
from_points.append(roi_points[2])
from_points.append(roi_points[3])

eye_width = roi_points[1][0] -roi_points[0][0]
eye_height = roi_points[3][1] - roi_points[0][1]
ratio = eye_height/eye_width
print(ratio)
move_y = int(round(move_x*ratio))
print(move_y)
#四隅
to_points.append((from_points[0][0]+move_x,from_points[0][1]+move_y))
to_points.append((from_points[1][0]-move_x,from_points[1][1]+move_y))
to_points.append((from_points[2][0]-move_x,from_points[2][1]-move_y))
to_points.append((from_points[3][0]+move_x,from_points[3][1]-move_y))


x_center = (roi_points[0][0]+roi_points[1][0])/2
y_center = (roi_points[0][1]+roi_points[3][1])/2

from_points.append( (int(x_center),roi_points[0][1]) )
to_points.append((int(x_center),roi_points[0][1]+2))

from_points.append( (int(x_center), roi_points[2][1]) )
to_points.append((int(x_center),roi_points[2][1]-2 ))

# print("roi:",roi_points)
# print("from:",from_points)
# print("to:",to_points)

#ここからdistort
file_path = './img/before.jpg'   
im = distort(file_path, roi_points, from_points, to_points)
im.show()



##############こっからもう一個
roi_points = []  
from_points = []  
to_points = [] 

roi_points.append(all_roi_points[4])
roi_points.append(all_roi_points[5])
roi_points.append(all_roi_points[6])
roi_points.append(all_roi_points[7])


from_points.append(roi_points[0])
from_points.append(roi_points[1])
from_points.append(roi_points[2])
from_points.append(roi_points[3])

eye_width = roi_points[1][0] -roi_points[0][0]
eye_height = roi_points[3][1] - roi_points[0][1]
ratio = eye_height/eye_width
print(ratio)
move_y = int(round(move_x*ratio))
print(move_y)
#四隅
to_points.append((from_points[0][0]+move_x,from_points[0][1]+move_y))
to_points.append((from_points[1][0]-move_x,from_points[1][1]+move_y))
to_points.append((from_points[2][0]-move_x,from_points[2][1]-move_y))
to_points.append((from_points[3][0]+move_x,from_points[3][1]-move_y))


x_center = (roi_points[0][0]+roi_points[1][0])/2
y_center = (roi_points[0][1]+roi_points[3][1])/2

from_points.append( (int(x_center),roi_points[0][1]) )
to_points.append((int(x_center),roi_points[0][1]+2))

from_points.append( (int(x_center), roi_points[2][1]) )
to_points.append((int(x_center),roi_points[2][1]-2 ))

# print("roi:",roi_points)
# print("from:",from_points)
# print("to:",to_points)

#ここからdistort
file_path = './img/before.jpg'   
im = distort(file_path, roi_points, from_points, to_points)
im.show()
# Out:
# 0.631578947368
# 3

# %%
original_img = cv2.imread("./img/before.jpg")

#ベクトルだけの表示
# cv2.rectangle(check_vec_img, roi_points[0], roi_points[2], (0, 0, 255), 1)
for i in range(0,len(from_points)):
    cv2.line(original_img, from_points[i], to_points[i], (255, 255, 255), 3)
    cv2.line(original_img, to_points[i], to_points[i], (255, 0, 0), 5)

print("原画")
display_cv_image(original_img)
# Out:
# 原画

# %%
# Out:
# [(10, 2), (4, 5)]
